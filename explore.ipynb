# %%
import pandas
pandas.set_option('display.max_columns', None)

# %%
airbnb = pandas.read_csv("airbnb_open_data.csv", low_memory= False)

# %%
m = airbnb.groupby(["neighbourhood","instant_bookable"])["instant_bookable"].value_counts().to_frame()

# %%
m
# Out:
#                                                  instant_bookable
# neighbourhood instant_bookable instant_bookable
# Allerton      False            False                           47
#               True             True                            50
# Arden Heights False            False                            1
#               True             True                             8
# Arrochar      False            False                           24
# ...                                                           ...
# Woodlawn      True             True                            15
# Woodrow       False            False                            1
#               True             True                             2
# Woodside      False            False                          289
#               True             True                           299
#
# [444 rows x 1 columns]

# %%
airbnb.groupby('instant_bookable')["neighbourhood group"].value_counts().unstack(0).plot.barh(title = "Barplot of instant bookable option per district")
# Out:
# <AxesSubplot:title={'center':'Barplot of instant bookable option per district'}, ylabel='neighbourhood group'>

# %%
df = pandas.read_excel("uber_deliveryServiceDataset.xlsx")

# %%
df["RATION"] = df["Completes"]/df["Requests"]

# %%
airbnb.replace({'neighbourhood group': {"brookln":"Brooklyn"}})
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
m
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df["DAY_OF_WEEK"] = df[["Date"]].datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/47/k850xfkn7td8r556wg3s766m0000gn/T/ipykernel_5147/2222128468.py in <module>
# ----> 1 df["DAY_OF_WEEK"] = df[["Date"]].datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datetime'

# %%
df["Date"].dt.weekday_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/47/k850xfkn7td8r556wg3s766m0000gn/T/ipykernel_5147/774419504.py in <module>
# ----> 1 df["Date"].dt.weekday_name()
#
# AttributeError: 'DatetimeProperties' object has no attribute 'weekday_name'

# %%
import datetime as dt

# %%
import time

time.strftime('%A')
# Out:
# 'Tuesday'

# %%
df['hire_day_name'] = pandas.to_datetime(df['Date']).dt.day_name()

# %%
df.groupby(["Hour"])["Requests"].mean()
# Out:
# Hour
# 11    200.266667
# 12    284.333333
# 13    215.966667
# Name: Requests, dtype: float64

# %%
df.groupby(["hire_day_name", "Hour"])["RATION"].mean().reset_index().sort_values(by="RATION")
# Out:
#    hire_day_name  Hour    RATION
# 2         Friday    13  0.331118
# 17       Tuesday    13  0.437026
# 19     Wednesday    12  0.514825
# 20     Wednesday    13  0.531526
# 14      Thursday    13  0.539684
# 18     Wednesday    11  0.562101
# 11        Sunday    13  0.574039
# 8       Saturday    13  0.596948
# 16       Tuesday    12  0.615811
# 1         Friday    12  0.619881
# 5         Monday    13  0.649619
# 15       Tuesday    11  0.658926
# 10        Sunday    12  0.691117
# 13      Thursday    12  0.707890
# 4         Monday    12  0.712054
# 12      Thursday    11  0.719269
# 7       Saturday    12  0.771563
# 9         Sunday    11  0.803142
# 3         Monday    11  0.816720
# 6       Saturday    11  0.833650
# 0         Friday    11  0.834544
